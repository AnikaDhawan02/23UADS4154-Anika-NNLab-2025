# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess data
x_train = x_train.reshape(-1, 784).astype(np.float32) / 255.0
x_test = x_test.reshape(-1, 784).astype(np.float32) / 255.0
y_train = tf.one_hot(y_train, depth=10)
y_test = tf.one_hot(y_test, depth=10)

# Hyperparameter combinations
hidden_layer_configs = [(160, 100), (100, 100), (100, 160), (60, 60), (100, 60)]
learning_rates = [0.01, 0.1, 1.0]
num_epochs = 20
batch_size = 10
n_input = 784
n_output = 10

# Iterate over different configurations
for (n_hidden1, n_hidden2) in hidden_layer_configs:
    for learning_rate in learning_rates:
        print(f"\nTraining with Hidden Layers: ({n_hidden1}, {n_hidden2}), Learning Rate: {learning_rate}")

        # Initialize weights and biases
        initializer = tf.initializers.GlorotUniform()
        W1 = tf.Variable(initializer([n_input, n_hidden1]))
        b1 = tf.Variable(tf.zeros([n_hidden1]))
        W2 = tf.Variable(initializer([n_hidden1, n_hidden2]))
        b2 = tf.Variable(tf.zeros([n_hidden2]))
        W3 = tf.Variable(initializer([n_hidden2, n_output]))
        b3 = tf.Variable(tf.zeros([n_output]))

        # Define forward pass
        def forward_pass(x):
            z1 = tf.add(tf.matmul(x, W1), b1)
            a1 = tf.nn.relu(z1)  # ReLU activation
            z2 = tf.add(tf.matmul(a1, W2), b2)
            a2 = tf.nn.relu(z2)  # ReLU activation
            logits = tf.add(tf.matmul(a2, W3), b3)
            return logits

        # Loss function
        def compute_loss(logits, labels):
            return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits))

        # Accuracy metric
        def compute_accuracy(logits, labels):
            correct_preds = tf.equal(tf.argmax(logits, axis=1), tf.argmax(labels, axis=1))
            return tf.reduce_mean(tf.cast(correct_preds, tf.float32))

        # Optimizer
        optimizer = tf.optimizers.SGD(learning_rate)

        # Training loop
        train_losses, test_accuracies = [], []
        start_time = time.time()
        for epoch in range(num_epochs):
            for i in range(0, x_train.shape[0], batch_size):
                x_batch = x_train[i:i + batch_size]
                y_batch = y_train[i:i + batch_size]

                with tf.GradientTape() as tape:
                    logits = forward_pass(x_batch)
                    loss = compute_loss(logits, y_batch)

                gradients = tape.gradient(loss, [W1, b1, W2, b2, W3, b3])
                optimizer.apply_gradients(zip(gradients, [W1, b1, W2, b2, W3, b3]))

            # Evaluate after each epoch
            test_logits = forward_pass(x_test)
            test_accuracy = compute_accuracy(test_logits, y_test)
            train_losses.append(loss.numpy())
            test_accuracies.append(test_accuracy.numpy())
            print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {loss.numpy():.4f}, Test Accuracy: {test_accuracy.numpy():.4f}")

        # Calculate execution time
        execution_time = time.time() - start_time
        print(f"Execution Time: {execution_time:.2f} seconds")

        # Plot loss and accuracy curves
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(range(1, num_epochs + 1), train_losses, marker='o', label='Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Loss Curve (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(range(1, num_epochs + 1), test_accuracies, marker='o', color='r', label='Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title(f'Accuracy Curve (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.legend()
        plt.show()

        # Confusion matrix
        y_pred = tf.argmax(forward_pass(x_test), axis=1).numpy()
        y_true = tf.argmax(y_test, axis=1).numpy()
        conf_matrix = confusion_matrix(y_true, y_pred)

        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title(f'Confusion Matrix (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.show()

        print("============================================")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Training with Hidden Layers: (160, 100), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0396, Test Accuracy: 0.9333
# Epoch 2/20, Loss: 0.0260, Test Accuracy: 0.9504
# Epoch 3/20, Loss: 0.0183, Test Accuracy: 0.9617
# Epoch 4/20, Loss: 0.0139, Test Accuracy: 0.9667
# Epoch 5/20, Loss: 0.0108, Test Accuracy: 0.9700
# Epoch 6/20, Loss: 0.0088, Test Accuracy: 0.9722
# Epoch 7/20, Loss: 0.0074, Test Accuracy: 0.9732
# Epoch 8/20, Loss: 0.0065, Test Accuracy: 0.9748
# Epoch 9/20, Loss: 0.0058, Test Accuracy: 0.9751
# Epoch 10/20, Loss: 0.0051, Test Accuracy: 0.9755
# Epoch 11/20, Loss: 0.0045, Test Accuracy: 0.9757
# Epoch 12/20, Loss: 0.0038, Test Accuracy: 0.9758
# Epoch 13/20, Loss: 0.0034, Test Accuracy: 0.9766
# Epoch 14/20, Loss: 0.0030, Test Accuracy: 0.9769
# Epoch 15/20, Loss: 0.0026, Test Accuracy: 0.9764
# Epoch 16/20, Loss: 0.0027, Test Accuracy: 0.9765
# Epoch 17/20, Loss: 0.0027, Test Accuracy: 0.9768
# Epoch 18/20, Loss: 0.0023, Test Accuracy: 0.9763
# Epoch 19/20, Loss: 0.0022, Test Accuracy: 0.9769
# Epoch 20/20, Loss: 0.0022, Test Accuracy: 0.9766
# Execution Time: 1930.25 seconds
# ============================================
#
# Training with Hidden Layers: (160, 100), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0023, Test Accuracy: 0.9504
# Epoch 2/20, Loss: 0.0006, Test Accuracy: 0.9646
# Epoch 3/20, Loss: 0.0002, Test Accuracy: 0.9672
# Epoch 4/20, Loss: 0.0001, Test Accuracy: 0.9717
# Epoch 5/20, Loss: 0.0004, Test Accuracy: 0.9690
# Epoch 6/20, Loss: 0.0015, Test Accuracy: 0.9770
# Epoch 7/20, Loss: 0.0007, Test Accuracy: 0.9723
# Epoch 8/20, Loss: 0.0000, Test Accuracy: 0.9745
# Epoch 9/20, Loss: 0.0001, Test Accuracy: 0.9751
# Epoch 10/20, Loss: 0.0000, Test Accuracy: 0.9741
# Epoch 11/20, Loss: 0.0017, Test Accuracy: 0.9738
# Epoch 12/20, Loss: 0.0004, Test Accuracy: 0.9781
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9778
# Epoch 14/20, Loss: 0.0000, Test Accuracy: 0.9779
# Epoch 15/20, Loss: 0.0007, Test Accuracy: 0.9769
# Epoch 16/20, Loss: 0.0000, Test Accuracy: 0.9758
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9764
# Epoch 18/20, Loss: 0.0000, Test Accuracy: 0.9719
# Epoch 19/20, Loss: 0.0001, Test Accuracy: 0.9790
# Epoch 20/20, Loss: 0.0003, Test Accuracy: 0.9782
# Execution Time: 1921.22 seconds
# ============================================
#
# Training with Hidden Layers: (160, 100), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1905.50 seconds
# ============================================
#
# Training with Hidden Layers: (100, 100), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0440, Test Accuracy: 0.9307
# Epoch 2/20, Loss: 0.0271, Test Accuracy: 0.9486
# Epoch 3/20, Loss: 0.0173, Test Accuracy: 0.9573
# Epoch 4/20, Loss: 0.0128, Test Accuracy: 0.9627
# Epoch 5/20, Loss: 0.0100, Test Accuracy: 0.9661
# Epoch 6/20, Loss: 0.0082, Test Accuracy: 0.9695
# Epoch 7/20, Loss: 0.0066, Test Accuracy: 0.9717
# Epoch 8/20, Loss: 0.0059, Test Accuracy: 0.9722
# Epoch 9/20, Loss: 0.0052, Test Accuracy: 0.9730
# Epoch 10/20, Loss: 0.0048, Test Accuracy: 0.9741
# Epoch 11/20, Loss: 0.0041, Test Accuracy: 0.9746
# Epoch 12/20, Loss: 0.0037, Test Accuracy: 0.9745
# Epoch 13/20, Loss: 0.0036, Test Accuracy: 0.9751
# Epoch 14/20, Loss: 0.0035, Test Accuracy: 0.9749
# Epoch 15/20, Loss: 0.0032, Test Accuracy: 0.9745
# Epoch 16/20, Loss: 0.0030, Test Accuracy: 0.9743
# Epoch 17/20, Loss: 0.0027, Test Accuracy: 0.9743
# Epoch 18/20, Loss: 0.0023, Test Accuracy: 0.9745
# Epoch 19/20, Loss: 0.0021, Test Accuracy: 0.9753
# Epoch 20/20, Loss: 0.0019, Test Accuracy: 0.9751
# Execution Time: 1817.99 seconds
# ============================================
#
# Training with Hidden Layers: (100, 100), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0033, Test Accuracy: 0.9541
# Epoch 2/20, Loss: 0.0027, Test Accuracy: 0.9594
# Epoch 3/20, Loss: 0.0005, Test Accuracy: 0.9680
# Epoch 4/20, Loss: 0.0002, Test Accuracy: 0.9655
# Epoch 5/20, Loss: 0.0001, Test Accuracy: 0.9694
# Epoch 6/20, Loss: 0.0003, Test Accuracy: 0.9730
# Epoch 7/20, Loss: 0.0030, Test Accuracy: 0.9730
# Epoch 8/20, Loss: 0.0002, Test Accuracy: 0.9697
# Epoch 9/20, Loss: 0.0000, Test Accuracy: 0.9729
# Epoch 10/20, Loss: 0.0000, Test Accuracy: 0.9745
# Epoch 11/20, Loss: 0.0001, Test Accuracy: 0.9732
# Epoch 12/20, Loss: 0.0000, Test Accuracy: 0.9734
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9726
# Epoch 14/20, Loss: 0.0000, Test Accuracy: 0.9731
# Epoch 15/20, Loss: 0.0000, Test Accuracy: 0.9731
# Epoch 16/20, Loss: 0.0006, Test Accuracy: 0.9740
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9764
# Epoch 18/20, Loss: 0.0000, Test Accuracy: 0.9752
# Epoch 19/20, Loss: 0.0000, Test Accuracy: 0.9741
# Epoch 20/20, Loss: 0.0000, Test Accuracy: 0.9750
# Execution Time: 1824.09 seconds
# ============================================
#
# Training with Hidden Layers: (100, 100), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1838.13 seconds
# ============================================
#
# Training with Hidden Layers: (100, 160), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0433, Test Accuracy: 0.9284
# Epoch 2/20, Loss: 0.0264, Test Accuracy: 0.9486
# Epoch 3/20, Loss: 0.0185, Test Accuracy: 0.9576
# Epoch 4/20, Loss: 0.0141, Test Accuracy: 0.9624
# Epoch 5/20, Loss: 0.0102, Test Accuracy: 0.9662
# Epoch 6/20, Loss: 0.0084, Test Accuracy: 0.9705
# Epoch 7/20, Loss: 0.0071, Test Accuracy: 0.9725
# Epoch 8/20, Loss: 0.0061, Test Accuracy: 0.9735
# Epoch 9/20, Loss: 0.0050, Test Accuracy: 0.9746
# Epoch 10/20, Loss: 0.0044, Test Accuracy: 0.9751
# Epoch 11/20, Loss: 0.0038, Test Accuracy: 0.9754
# Epoch 12/20, Loss: 0.0034, Test Accuracy: 0.9760
# Epoch 13/20, Loss: 0.0030, Test Accuracy: 0.9763
# Epoch 14/20, Loss: 0.0026, Test Accuracy: 0.9761
# Epoch 15/20, Loss: 0.0023, Test Accuracy: 0.9770
# Epoch 16/20, Loss: 0.0021, Test Accuracy: 0.9768
# Epoch 17/20, Loss: 0.0019, Test Accuracy: 0.9767
# Epoch 18/20, Loss: 0.0017, Test Accuracy: 0.9770
# Epoch 19/20, Loss: 0.0016, Test Accuracy: 0.9770
# Epoch 20/20, Loss: 0.0014, Test Accuracy: 0.9774
# Execution Time: 1866.33 seconds
# ============================================
#
# Training with Hidden Layers: (100, 160), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0051, Test Accuracy: 0.9589
# Epoch 2/20, Loss: 0.0010, Test Accuracy: 0.9629
# Epoch 3/20, Loss: 0.0023, Test Accuracy: 0.9618
# Epoch 4/20, Loss: 0.0002, Test Accuracy: 0.9699
# Epoch 5/20, Loss: 0.0022, Test Accuracy: 0.9667
# Epoch 6/20, Loss: 0.0008, Test Accuracy: 0.9718
# Epoch 7/20, Loss: 0.0008, Test Accuracy: 0.9648
# Epoch 8/20, Loss: 0.0000, Test Accuracy: 0.9705
# Epoch 9/20, Loss: 0.0002, Test Accuracy: 0.9698
# Epoch 10/20, Loss: 0.0000, Test Accuracy: 0.9710
# Epoch 11/20, Loss: 0.0001, Test Accuracy: 0.9694
# Epoch 12/20, Loss: 0.0002, Test Accuracy: 0.9728
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9747
# Epoch 14/20, Loss: 0.0001, Test Accuracy: 0.9755
# Epoch 15/20, Loss: 0.0019, Test Accuracy: 0.9735
# Epoch 16/20, Loss: 0.0040, Test Accuracy: 0.9667
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9766
# Epoch 18/20, Loss: 0.0006, Test Accuracy: 0.9760
# Epoch 19/20, Loss: 0.0000, Test Accuracy: 0.9786
# Epoch 20/20, Loss: 0.0000, Test Accuracy: 0.9778
# Execution Time: 1842.86 seconds
# ============================================
#
# Training with Hidden Layers: (100, 160), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1832.27 seconds
# ============================================
#
# Training with Hidden Layers: (60, 60), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0477, Test Accuracy: 0.9225
# Epoch 2/20, Loss: 0.0289, Test Accuracy: 0.9414
# Epoch 3/20, Loss: 0.0216, Test Accuracy: 0.9524
# Epoch 4/20, Loss: 0.0156, Test Accuracy: 0.9595
# Epoch 5/20, Loss: 0.0118, Test Accuracy: 0.9643
# Epoch 6/20, Loss: 0.0093, Test Accuracy: 0.9674
# Epoch 7/20, Loss: 0.0075, Test Accuracy: 0.9695
# Epoch 8/20, Loss: 0.0062, Test Accuracy: 0.9713
# Epoch 9/20, Loss: 0.0050, Test Accuracy: 0.9719
# Epoch 10/20, Loss: 0.0039, Test Accuracy: 0.9721
# Epoch 11/20, Loss: 0.0031, Test Accuracy: 0.9722
# Epoch 12/20, Loss: 0.0025, Test Accuracy: 0.9727
# Epoch 13/20, Loss: 0.0019, Test Accuracy: 0.9730
# Epoch 14/20, Loss: 0.0017, Test Accuracy: 0.9733
# Epoch 15/20, Loss: 0.0014, Test Accuracy: 0.9732
# Epoch 16/20, Loss: 0.0012, Test Accuracy: 0.9732
# Epoch 17/20, Loss: 0.0011, Test Accuracy: 0.9736
# Epoch 18/20, Loss: 0.0009, Test Accuracy: 0.9738
# Epoch 19/20, Loss: 0.0008, Test Accuracy: 0.9729
# Epoch 20/20, Loss: 0.0006, Test Accuracy: 0.9733
# Execution Time: 1790.07 seconds
# ============================================
#
# Training with Hidden Layers: (60, 60), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0115, Test Accuracy: 0.9464
# Epoch 2/20, Loss: 0.0030, Test Accuracy: 0.9590
# Epoch 3/20, Loss: 0.0023, Test Accuracy: 0.9667
# Epoch 4/20, Loss: 0.0007, Test Accuracy: 0.9619
# Epoch 5/20, Loss: 0.0008, Test Accuracy: 0.9667
# Epoch 6/20, Loss: 0.0003, Test Accuracy: 0.9612
# Epoch 7/20, Loss: 0.0002, Test Accuracy: 0.9685
# Epoch 8/20, Loss: 0.0001, Test Accuracy: 0.9676
# Epoch 9/20, Loss: 0.0001, Test Accuracy: 0.9666
# Epoch 10/20, Loss: 0.0001, Test Accuracy: 0.9604
# Epoch 11/20, Loss: 0.0004, Test Accuracy: 0.9672
# Epoch 12/20, Loss: 0.0002, Test Accuracy: 0.9641
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9691
# Epoch 14/20, Loss: 0.0000, Test Accuracy: 0.9690
# Epoch 15/20, Loss: 0.0000, Test Accuracy: 0.9678
# Epoch 16/20, Loss: 0.0122, Test Accuracy: 0.9699
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9721
# Epoch 18/20, Loss: 0.0000, Test Accuracy: 0.9717
# Epoch 19/20, Loss: 0.0000, Test Accuracy: 0.9656
# Epoch 20/20, Loss: 0.0000, Test Accuracy: 0.9649
# Execution Time: 1789.24 seconds
# ============================================
#
# Training with Hidden Layers: (60, 60), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1812.26 seconds
# ============================================
#
# Training with Hidden Layers: (100, 60), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0426, Test Accuracy: 0.9286
# Epoch 2/20, Loss: 0.0263, Test Accuracy: 0.9471
# Epoch 3/20, Loss: 0.0162, Test Accuracy: 0.9542
# Epoch 4/20, Loss: 0.0108, Test Accuracy: 0.9604
# Epoch 5/20, Loss: 0.0079, Test Accuracy: 0.9651
# Epoch 6/20, Loss: 0.0061, Test Accuracy: 0.9675
# Epoch 7/20, Loss: 0.0050, Test Accuracy: 0.9698
# Epoch 8/20, Loss: 0.0042, Test Accuracy: 0.9718
# Epoch 9/20, Loss: 0.0037, Test Accuracy: 0.9726
# Epoch 10/20, Loss: 0.0030, Test Accuracy: 0.9738
# Epoch 11/20, Loss: 0.0028, Test Accuracy: 0.9747
# Epoch 12/20, Loss: 0.0023, Test Accuracy: 0.9749
# Epoch 13/20, Loss: 0.0019, Test Accuracy: 0.9754
# Epoch 14/20, Loss: 0.0016, Test Accuracy: 0.9757
# Epoch 15/20, Loss: 0.0014, Test Accuracy: 0.9762
# Epoch 16/20, Loss: 0.0013, Test Accuracy: 0.9759
# Epoch 17/20, Loss: 0.0011, Test Accuracy: 0.9761
# Epoch 18/20, Loss: 0.0010, Test Accuracy: 0.9764
# Epoch 19/20, Loss: 0.0010, Test Accuracy: 0.9764
# Epoch 20/20, Loss: 0.0008, Test Accuracy: 0.9769
# Execution Time: 1861.73 seconds
# ============================================
#
# Training with Hidden Layers: (100, 60), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0054, Test Accuracy: 0.9495
# Epoch 2/20, Loss: 0.0012, Test Accuracy: 0.9650
# Epoch 3/20, Loss: 0.0006, Test Accuracy: 0.9689
# Epoch 4/20, Loss: 0.0007, Test Accuracy: 0.9613
# Epoch 5/20, Loss: 0.0003, Test Accuracy: 0.9669
# Epoch 6/20, Loss: 0.0066, Test Accuracy: 0.9673
# Epoch 7/20, Loss: 0.0017, Test Accuracy: 0.9738
# Epoch 8/20, Loss: 0.0000, Test Accuracy: 0.9674
# Epoch 9/20, Loss: 0.0001, Test Accuracy: 0.9708
# Epoch 10/20, Loss: 0.0000, Test Accuracy: 0.9677
# Epoch 11/20, Loss: 0.0002, Test Accuracy: 0.9700
# Epoch 12/20, Loss: 0.0000, Test Accuracy: 0.9684
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9747
# Epoch 14/20, Loss: 0.0000, Test Accuracy: 0.9766
# Epoch 15/20, Loss: 0.0000, Test Accuracy: 0.9759
# Epoch 16/20, Loss: 0.0000, Test Accuracy: 0.9735
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9699
# Epoch 18/20, Loss: 0.0000, Test Accuracy: 0.9759
# Epoch 19/20, Loss: 0.0001, Test Accuracy: 0.9723
# Epoch 20/20, Loss: 0.0006, Test Accuracy: 0.9752
# Execution Time: 1848.73 seconds
# ============================================
#
# Training with Hidden Layers: (100, 60), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
